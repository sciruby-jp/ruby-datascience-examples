# %% [markdown]
# # statsample を用いた散布図の作り方

# %%
require 'statsample'
include Statsample::Shorthand

n = 100
x = rnorm(n)
y = x + rnorm(n,0.5,0.2)
Statsample::Graph::Scatterplot.new(x,y)
# Out:
# NOTE: Daru::Vector#has_missing_data? is deprecated; use include_values? instead. It will be removed on or after 2016-10-01.
# Daru::Vector#has_missing_data? called from /var/lib/gems/2.3.0/gems/statsample-2.0.2/lib/statsample.rb:217.
# NOTE: Daru::Vector#has_missing_data? is deprecated; use include_values? instead. It will be removed on or after 2016-10-01.
# Daru::Vector#has_missing_data? called from /var/lib/gems/2.3.0/gems/statsample-2.0.2/lib/statsample.rb:217.
# #<Statsample::Graph::Scatterplot:0x000000036a0d80 @v2_name=nil, @v1_name=nil, @v1=#<Daru::Vector(100)>
#                     0   0.7835494442408307
#                     1  0.23770900307339513
#                     2 -0.20379080995542445
#                     3  -0.4452011190446526
#                     4  0.03520473493215662
#                     5   1.8033973599206143
#                     6 -0.02107233385935189
#                     7   -1.460359823672893
#                     8  -0.8748285117610685
# ...
